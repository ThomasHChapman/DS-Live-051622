# %% [markdown]
# # Aggregating and Combining `pandas` DataFrames

# %% [markdown]
# ## Objectives

# %% [markdown]
# - Use GroupBy objects to organize and aggregate data
# - Create pivot tables from DataFrames
# - Combine DataFrames by merging, joining, and concatinating

# %% [markdown]
# ## Set Up

# %% [markdown]
# Surprise, surprise... we're still working with the Austin Animal Center Data! Let's start with Outcomes

# %%
# Imports
import pandas as pd
import numpy as np

import matplotlib as plt

# %%
outcomes = pd.read_csv('data/Austin_Animal_Center_Outcomes_022822.csv', parse_dates=['DateTime', 'Date of Birth'])

# %% [markdown]
# outcomes.head()

# %%
# Let's create our Age in Days column
outcomes['Calculated Age in days'] = pd.to_datetime(outcomes['DateTime'].dt.date) - outcomes['Date of Birth']

# %%
# Grab just the integer here...
outcomes['Calculated Age in days'] = outcomes['Calculated Age in days'].astype(int)

# %%
# Sanity check
outcomes.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  \
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby
#
#    Calculated Age in days
# 0       63590400000000000
# 1       32054400000000000
# 2       31622400000000000
# 3       11059200000000000
# 4         518400000000000

# %% [markdown]
# ## Aggregating over DataFrames: `.groupby()`

# %% [markdown]
# Those of you familiar with SQL have probably used the GROUP BY command. (And if you haven't, you'll see it very soon!) Pandas has this, too.
#
# The `.groupby()` method is especially useful for aggregate functions applied to the data grouped in particular ways.

# %%
# Just using groupby outputs some weird GroupBy object... not helpful
type(outcomes.groupby('Animal Type'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# Once we know we are working with a type of object, it opens up a suite of attributes and methods. One attribute we can look at is `groups`.

# %%
outcomes[outcomes['Animal Type'] == 'Bird']
# Out:
#        Animal ID        Name            DateTime MonthYear Date of Birth  \
# 206      A720727  Rooster 11 2016-03-08 13:47:00  Mar 2016    2015-02-14
# 534      A720734  Rooster 18 2016-03-08 15:07:00  Mar 2016    2015-02-14
# 985      A779213         NaN 2018-09-07 11:17:00  Sep 2018    2017-08-27
# 1027     A760051         NaN 2017-10-20 12:40:00  Oct 2017    2016-10-11
# 1284     A790172         NaN 2019-03-07 00:00:00  Mar 2019    2018-03-05
# ...          ...         ...                 ...       ...           ...
# 136331   A851000     A851000 2022-02-03 16:39:00  Feb 2022    2020-02-03
# 136332   A850997     A850997 2022-02-03 16:38:00  Feb 2022    2020-02-03
# 136376   A850996  Yukon Jack 2022-02-04 09:52:00  Feb 2022    2019-02-03
# 136463   A851114         NaN 2022-02-09 15:32:00  Feb 2022    2021-02-06
# 136501   A851113         NaN 2022-02-10 08:07:00  Feb 2022    2022-01-06
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 206        Adoption             NaN        Bird      Intact Male
# 534        Adoption             NaN        Bird      Intact Male
# 985        Adoption          Foster        Bird          Unknown
# 1027       Adoption             NaN        Bird          Unknown
# 1284     Euthanasia       Suffering        Bird          Unknown
# ...             ...             ...         ...              ...
# 136331   Euthanasia       Suffering        Bird          Unknown
# 136332   Euthanasia       Suffering        Bird          Unknown
# 136376     Transfer         Partner        Bird      Intact Male
# 136463     Transfer         Partner        Bird      Intact Male
# 136501     Transfer         Partner        Bird          Unknown
#
#        Age upon Outcome        Breed            Color  Calculated Age in days
# 206              1 year  Chicken Mix        Black/Red       33523200000000000
# 534              1 year  Chicken Mix  Black/Chocolate       33523200000000000
# 985              1 year   Quaker Mix     Green/Silver       32486400000000000
# 1027             1 year       Quaker       Green/Gray       32313600000000000
# 1284             1 year  Chicken Mix        White/Red       31708800000000000
# ...                 ...          ...              ...                     ...
# 136331          2 years       Pigeon       Gray/White       63158400000000000
# 136332          2 years       Pigeon       Gray/White       63158400000000000
# 136376          3 years       Falcon      Brown/White       94780800000000000
# 136463           1 year      Chicken   Tricolor/White       31795200000000000
# 136501          5 weeks      Chicken     Yellow/White        3024000000000000
#
# [636 rows x 13 columns]

# %%
# This returns each group indexed by the group name, e.g. 'Bird',
# along with the row indices of each value
outcomes.groupby('Animal Type').groups
# Out:
# {'Bird': [206, 534, 985, 1027, 1284, 1310, 2220, 2258, 2274, 2417, 2521, 2598, 2712, 2778, 3178, 3379, 3648, 3743, 4003, 4024, 4288, 4702, 4766, 4998, 5063, 5205, 5436, 5656, 5848, 6087, 6236, 6340, 6592, 6682, 7033, 7352, 7428, 7985, 8048, 8315, 8331, 8414, 8538, 8922, 9203, 9448, 9758, 9825, 10103, 10165, 10407, 10657, 10736, 11386, 11616, 11674, 11732, 11765, 11771, 11837, 12205, 12418, 12423, 12451, 12474, 12713, 12902, 12978, 13057, 13063, 13095, 13272, 13317, 13323, 13435, 13474, 13677, 13934, 13950, 13963, 13981, 14108, 14131, 14146, 14193, 15114, 15193, 15543, 15553, 15813, 16022, 16197, 16499, 16866, 17173, 17338, 17390, 17426, 18319, 18359, ...], 'Cat': [0, 4, 7, 8, 10, 11, 14, 15, 16, 17, 18, 20, 24, 26, 34, 37, 49, 54, 56, 66, 67, 68, 70, 75, 78, 80, 83, 84, 89, 90, 92, 94, 95, 97, 98, 102, 113, 115, 116, 117, 118, 120, 122, 126, 139, 141, 142, 145, 147, 148, 151, 152, 156, 157, 158, 164, 167, 168, 170, 171, 176, 178, 184, 191, 192, 194, 200, 202, 203, 207, 209, 212, 215, 219, 223, 226, 227, 230, 238, 240, 245, 246, 251, 254, 255, 257, 261, 266, 267, 268, 273, 274, 275, 278, 279, 281, 282, 285, 288, 290, ...], 'Dog': [1, 3, 5, 6, 9, 12, 13, 21, 22, 23, 25, 28, 29, 30, 31, 32, 35, 36, 38, 39, 41, 42, 43, 45, 46, 47, 48, 50, 51, 52, 55, 57, 58, 59, 60, 61, 62, 63, 64, 65, 69, 73, 74, 76, 79, 81, 82, 85, 86, 87, 88, 91, 93, 96, 99, 100, 101, 104, 105, 106, 107, 108, 109, 110, 111, 112, 114, 119, 121, 123, 124, 125, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 140, 143, 144, 146, 149, 153, 154, 155, 159, 160, 161, 162, 163, 165, 166, 169, ...], 'Livestock': [2395, 5763, 8413, 10286, 13275, 14428, 20614, 26426, 32095, 38456, 50988, 51860, 77293, 78037, 83520, 98309, 103897, 104154, 107242, 108520, 113321, 117427, 127774, 129632, 131330], 'Other': [2, 19, 27, 33, 40, 44, 53, 71, 72, 77, 103, 150, 172, 177, 185, 235, 243, 263, 280, 298, 344, 406, 411, 412, 422, 479, 506, 526, 544, 572, 580, 581, 605, 608, 633, 638, 711, 717, 725, 736, 743, 765, 811, 838, 841, 861, 867, 886, 896, 926, 949, 1067, 1068, 1074, 1090, 1092, 1165, 1188, 1195, 1203, 1210, 1238, 1245, 1282, 1308, 1348, 1363, 1391, 1409, 1421, 1453, 1464, 1471, 1473, 1476, 1509, 1560, 1595, 1629, 1663, 1676, 1691, 1695, 1742, 1748, 1763, 1778, 1807, 1814, 1837, 1848, 1852, 1858, 1887, 1912, 1928, 1938, 1954, 1956, 1968, ...]}

# %%
# Same goes for multi-index groupbys
animal_outcome = outcomes.groupby(['Animal Type', 'Outcome Type'])

# %%
# .groups outputs a dictionary, so we can access the group names using keys()
type(animal_outcome.groups)
# Out:
# pandas.io.formats.printing.PrettyDict

# %%
animal_outcome.groups.keys()
# Out:
# dict_keys([('Cat', 'Rto-Adopt'), ('Dog', 'Adoption'), ('Other', 'Euthanasia'), ('Cat', 'Transfer'), ('Cat', 'Adoption'), ('Cat', 'Return to Owner'), ('Dog', 'Return to Owner'), ('Dog', 'Transfer'), ('Cat', 'Euthanasia'), ('Other', 'Adoption'), ('Dog', 'Rto-Adopt'), ('Cat', 'Died'), ('Dog', 'Euthanasia'), ('Other', 'Transfer'), ('Bird', 'Adoption'), ('Other', 'Disposal'), ('Other', 'Died'), ('Dog', 'Died'), ('Cat', 'Disposal'), ('Other', 'Return to Owner'), ('Bird', 'Euthanasia'), ('Bird', 'Transfer'), ('Livestock', 'Return to Owner'), ('Dog', 'Missing'), ('Other', 'Relocate'), ('Dog', nan), ('Livestock', 'Adoption'), ('Bird', 'Return to Owner'), ('Dog', 'Disposal'), ('Cat', 'Missing'), ('Bird', 'Disposal'), ('Bird', 'Died'), ('Other', 'Missing'), ('Other', 'Rto-Adopt'), ('Bird', 'Relocate'), ('Bird', 'Missing'), ('Other', nan), ('Livestock', 'Transfer'), ('Cat', 'Relocate'), ('Cat', nan), ('Livestock', 'Died'), ('Livestock', 'Euthanasia')])

# %%
# We can then get a specific group, such as cats that were adopted
animal_outcome.get_group(('Cat', 'Adoption'))
# Out:
#        Animal ID         Name            DateTime MonthYear Date of Birth  \
# 7        A689724   *Donatello 2014-10-18 18:52:00  Oct 2014    2014-08-01
# 8        A680969        *Zeus 2014-08-05 16:59:00  Aug 2014    2014-06-03
# 20       A730621        *Liza 2016-09-10 18:59:00  Sep 2016    2016-05-18
# 26       A801106          NaN 2019-08-16 14:05:00  Aug 2019    2019-05-06
# 54       A792258       Vesper 2019-04-10 20:53:00  Apr 2019    2016-09-08
# ...          ...          ...                 ...       ...           ...
# 137072   A846689  Coco Chanel 2022-02-26 17:23:00  Feb 2022    2021-08-19
# 137073   A845330        Mitzi 2022-02-26 18:09:00  Feb 2022    2021-01-28
# 137088   A851184      *Papaya 2022-02-28 11:38:00  Feb 2022    2021-02-08
# 137090   A847804     *Mahalia 2022-02-28 11:42:00  Feb 2022    2011-12-08
# 137092   A850166       Rainey 2022-01-24 18:20:00  Jan 2022    2021-11-19
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 7          Adoption             NaN         Cat    Neutered Male
# 8          Adoption             NaN         Cat    Neutered Male
# 20         Adoption             NaN         Cat    Spayed Female
# 26         Adoption             NaN         Cat    Neutered Male
# 54         Adoption             NaN         Cat    Spayed Female
# ...             ...             ...         ...              ...
# 137072     Adoption             NaN         Cat    Spayed Female
# 137073     Adoption             NaN         Cat    Spayed Female
# 137088     Adoption             NaN         Cat    Spayed Female
# 137090     Adoption             NaN         Cat    Spayed Female
# 137092     Adoption             NaN         Cat      Intact Male
#
#        Age upon Outcome                   Breed               Color  \
# 7              2 months  Domestic Shorthair Mix               Black
# 8              2 months  Domestic Shorthair Mix  White/Orange Tabby
# 20             3 months  Domestic Shorthair Mix              Calico
# 26             3 months      Domestic Shorthair        Orange Tabby
# 54              2 years  Domestic Shorthair Mix              Tortie
# ...                 ...                     ...                 ...
# 137072         6 months      Domestic Shorthair          Blue Tabby
# 137073           1 year      Domestic Shorthair        Torbie/White
# 137088           1 year  Domestic Shorthair Mix  Orange Tabby/White
# 137090         10 years  Domestic Shorthair Mix   Brown Tabby/White
# 137092         2 months                 Siamese          Seal Point
#
#         Calculated Age in days
# 7             6739200000000000
# 8             5443200000000000
# 20            9936000000000000
# 26            8812800000000000
# 54           81561600000000000
# ...                        ...
# 137072       16502400000000000
# 137073       34041600000000000
# 137088       33264000000000000
# 137090      322704000000000000
# 137092        5702400000000000
#
# [24810 rows x 13 columns]

# %% [markdown]
# ## Aggregating

# %% [markdown]
# Once again, as we will see in SQL, groupby objects are intended to be used with aggregation. In SQL, we will see that our queries that include GROUP BY require aggregation performed on columns.
#
# We can use `.sum()`, `.mean()`, `.count()`, `.max()`, `.min()`, etc. Find a list of common aggregations [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html).

# %%
# For each animal type, we will count up the values of each column.
outcomes.groupby('Animal Type').count()
# Out:
#              Animal ID   Name  DateTime  MonthYear  Date of Birth  \
# Animal Type
# Bird               636    145       636        636            636
# Cat              52092  30380     52092      52092          52092
# Dog              77091  64516     77091      77091          77091
# Livestock           25      3        25         25             25
# Other             7253   1051      7253       7253           7253
#
#              Outcome Type  Outcome Subtype  Sex upon Outcome  \
# Animal Type
# Bird                  636              380               636
# Cat                 52088            31815             52092
# Dog                 77076            24590             77089
# Livestock              25               19                25
# Other                7248             5849              7253
#
#              Age upon Outcome  Breed  Color  Calculated Age in days
# Animal Type
# Bird                      636    636    636                     636
# Cat                     52091  52092  52092                   52092
# Dog                     77089  77091  77091                   77091
# Livestock                  25     25     25                      25
# Other                    7251   7253   7253                    7253

# %% [markdown]
# ## Exercise

# %% [markdown]
# Use `.groupby()` to find the most recent birth date of each (main) animal type.

# %%
# Your code here
outcomes.groupby('Animal Type')['Date of Birth'].max()
# Out:
# Animal Type
# Bird        2022-01-06
# Cat         2022-02-18
# Dog         2022-02-14
# Livestock   2020-05-28
# Other       2022-02-11
# Name: Date of Birth, dtype: datetime64[ns]

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# outcomes.groupby('Animal Type')['Date of Birth'].max()
# ```
# </details>

# %%
outcomes.groupby(['Outcome Type', 'Sex upon Outcome']).agg('mean')
# Out:
#                                   Calculated Age in days
# Outcome Type    Sex upon Outcome
# Adoption        Intact Female          36245281069042320
#                 Intact Male            41177961290322584
#                 Neutered Male          56257303969406088
#                 Spayed Female          55991526701289056
#                 Unknown                33692914285714284
# Died            Intact Female          30207863414634148
#                 Intact Male            26299482352941176
#                 Neutered Male         160680902970297024
#                 Spayed Female         181431814736842112
#                 Unknown                26887052513966480
# Disposal        Intact Female          35188800000000000
#                 Intact Male            63584825806451616
#                 Neutered Male         171744000000000000
#                 Spayed Female         213422400000000000
#                 Unknown                38635143750000000
# Euthanasia      Intact Female          97927888235294112
#                 Intact Male            77973952293577984
#                 Neutered Male         192398789189189184
#                 Spayed Female         199901776271186432
#                 Unknown                43488022035195104
# Missing         Intact Female          23051520000000000
#                 Intact Male            29449107692307692
#                 Neutered Male         102667885714285712
#                 Spayed Female         109100160000000000
#                 Unknown                14623200000000000
# Relocate        Intact Female          63244800000000000
#                 Neutered Male          95472000000000000
#                 Spayed Female          42768000000000000
#                 Unknown                52894080000000000
# Return to Owner Intact Female          92193455172413792
#                 Intact Male            95924060497704752
#                 Neutered Male         141230300850545744
#                 Spayed Female         151291516046406944
#                 Unknown                66029063736263736
# Rto-Adopt       Intact Female         127970742857142864
#                 Intact Male           129874320000000000
#                 Neutered Male         108380123467230448
#                 Spayed Female         108179446153846160
#                 Unknown               137376000000000000
# Transfer        Intact Female          35380792334989356
#                 Intact Male            30348246724592404
#                 Neutered Male          97321730725957616
#                 Spayed Female          94835756962025312
#                 Unknown                14668586035933592

# %% [markdown]
# # Pivoting a DataFrame

# %% [markdown]
# ## `.pivot_table()`

# %% [markdown]
# Those of you familiar with Excel have probably used Pivot Tables. Pandas has a similar functionality.
#
# Grouping by two different columns can be very helpful.

# %%
outcomes.pivot_table(index = 'Outcome Type', columns = 'Sex upon Outcome', aggfunc = 'mean')
# Out:
#                  Calculated Age in days                              \
# Sex upon Outcome          Intact Female   Intact Male Neutered Male
# Outcome Type
# Adoption                   3.624528e+16  4.117796e+16  5.625730e+16
# Died                       3.020786e+16  2.629948e+16  1.606809e+17
# Disposal                   3.518880e+16  6.358483e+16  1.717440e+17
# Euthanasia                 9.792789e+16  7.797395e+16  1.923988e+17
# Missing                    2.305152e+16  2.944911e+16  1.026679e+17
# Relocate                   6.324480e+16           NaN  9.547200e+16
# Return to Owner            9.219346e+16  9.592406e+16  1.412303e+17
# Rto-Adopt                  1.279707e+17  1.298743e+17  1.083801e+17
# Transfer                   3.538079e+16  3.034825e+16  9.732173e+16
#
#
# Sex upon Outcome Spayed Female       Unknown
# Outcome Type
# Adoption          5.599153e+16  3.369291e+16
# Died              1.814318e+17  2.688705e+16
# Disposal          2.134224e+17  3.863514e+16
# Euthanasia        1.999018e+17  4.348802e+16
# Missing           1.091002e+17  1.462320e+16
# Relocate          4.276800e+16  5.289408e+16
# Return to Owner   1.512915e+17  6.602906e+16
# Rto-Adopt         1.081794e+17  1.373760e+17
# Transfer          9.483576e+16  1.466859e+16

# %% [markdown]
# But it has the unsavory side effect of creating a two-level index. This can be a good time to use `.pivot_table()`.
#
# (There is also a `.pivot()`. For the somewhat subtle differences, see [here](https://stackoverflow.com/questions/30960338/pandas-difference-between-pivot-and-pivot-table-why-is-only-pivot-table-workin).)

# %%
# Check it out!
outcomes.pivot(index= 'Outcome Type', columns= "Sex upon Outcome", values=)

# %% [markdown]
# # Methods for Combining DataFrames: `.join()`, `.merge()`, `.concat()`
#
# Many ways to combine dataframes! Luckily, pandas has great docs: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ## `.join()`

# %%
toy1 = pd.DataFrame([[63, 142], [33, 47]], columns=['age', 'HP'])
toy2 = pd.DataFrame([[63, 100], [33, 200]], columns=['age', 'MP'])

toy1
# Out:
#    age   HP
# 0   63  142
# 1   33   47

# %%
toy2
# Out:
#    age   MP
# 0   63  100
# 1   33  200

# %%
# We can't just join these as they are, since we haven't specified our suffixes

toy1.join(toy2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ab3e8f36fbb5> in <module>
#       1 # We can't just join these as they are, since we haven't specified our suffixes
#       2
# ----> 3 toy1.join(toy2)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
# --> 670         llabels, rlabels = _items_overlap_with_suffix(
#     671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2089
#    2090     if not lsuffix and not rsuffix:
# -> 2091         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2092
#    2093     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['age'], dtype='object')

# %%
toy1.join(toy2, lsuffix='1', rsuffix='2')
# Out:
#    age1   HP  age2   MP
# 0    63  142    63  100
# 1    33   47    33  200

# %% [markdown]
# If we don't want to keep both, we could set the overlapping column as the index in each DataFrame:

# %%
toy1.set_index('age').join(toy2.set_index('age'))
# Out:
#       HP   MP
# age
# 63   142  100
# 33    47  200

# %%
#or we could drop the age column from toy1 and join toy2

toy1.drop('age', axis = 1).join(toy2)
# Out:
#     HP  age   MP
# 0  142   63  100
# 1   47   33  200

# %% [markdown]
# ## `.merge()`

# %% [markdown]
# Or we could use `.merge()`:

# %%
# merge is way easier because it understands what the overlapping column is based on the column label.
toy1.merge(toy2)
# Out:
#    age   HP   MP
# 0   63  142  100
# 1   33   47  200

# %%
ds_chars = pd.read_csv('data/ds_chars.csv', index_col=0)
ds_chars
# Out:
#      name   HP home_state
# 0    greg  200         WA
# 1   miles  200         WA
# 2    alan  170         TX
# 3  alison  300         DC
# 4  rachel  200         TX

# %%
states = pd.read_csv('data/states.csv', index_col=0)
states
# Out:
#   state   nickname     capital
# 0    WA  evergreen     Olympia
# 1    TX      alamo      Austin
# 2    DC   district  Washington
# 3    OH    buckeye    Columbus
# 4    OR     beaver       Salem

# %%
#by defining the index names to merge, we can tell it where to merge the table.
ds_chars.merge(states, left_on='home_state', right_on='state')
# Out:
#      name   HP home_state state   nickname     capital
# 0    greg  200         WA    WA  evergreen     Olympia
# 1   miles  200         WA    WA  evergreen     Olympia
# 2    alan  170         TX    TX      alamo      Austin
# 3  rachel  200         TX    TX      alamo      Austin
# 4  alison  300         DC    DC   district  Washington

# %% [markdown]
# ## The `how` Parameter

# %% [markdown]
# This parameter in both `.join()` and `.merge()` tells the compiler what sort of join to effect. We'll cover this in detail when we discuss SQL.
#
# ![image showcasing how the how parameter in a join/merge would combine the two datasets, using venn-style diagrams](https://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png)
# [[Image Source]](https://www.datasciencemadesimple.com/join-merge-data-frames-pandas-python/)

# %%
# Not all rows from our source tables come in, because not all rows have a matching state.
ds_chars.merge(states, left_on='home_state', right_on='state', how='inner')
# Out:
#      name   HP home_state state   nickname     capital
# 0    greg  200         WA    WA  evergreen     Olympia
# 1   miles  200         WA    WA  evergreen     Olympia
# 2    alan  170         TX    TX      alamo      Austin
# 3  rachel  200         TX    TX      alamo      Austin
# 4  alison  300         DC    DC   district  Washington

# %%
ds_chars.merge(states, left_on='home_state', right_on='state', how='outer')
# using the outer method, we pulled all of both tables together, but because ds_chars had no information with an ohio or oregon
# state, then we end up with NaN values for those rows.
# Out:
#      name     HP home_state state   nickname     capital
# 0    greg  200.0         WA    WA  evergreen     Olympia
# 1   miles  200.0         WA    WA  evergreen     Olympia
# 2    alan  170.0         TX    TX      alamo      Austin
# 3  rachel  200.0         TX    TX      alamo      Austin
# 4  alison  300.0         DC    DC   district  Washington
# 5     NaN    NaN        NaN    OH    buckeye    Columbus
# 6     NaN    NaN        NaN    OR     beaver       Salem

# %%
# left join--keep all information from left table, but pull in matching, relevant info from right table.
# right join works identically in reverse--really don't use this, just make your right table the left table.

# in this example, left and inner return the same thing  because all of the data in ds_chars has a match in states.
ds_chars.merge(states, left_on='home_state', right_on='state', how='left')
# Out:
#      name   HP home_state state   nickname     capital
# 0    greg  200         WA    WA  evergreen     Olympia
# 1   miles  200         WA    WA  evergreen     Olympia
# 2    alan  170         TX    TX      alamo      Austin
# 3  alison  300         DC    DC   district  Washington
# 4  rachel  200         TX    TX      alamo      Austin

# %% [markdown]
# ## `pd.concat()`

# %% [markdown]
# This method takes a *list* of pandas objects as arguments.

# %%
ds_chars
# Out:
#      name   HP home_state
# 0    greg  200         WA
# 1   miles  200         WA
# 2    alan  170         TX
# 3  alison  300         DC
# 4  rachel  200         TX

# %%
prefs = pd.read_csv('data/preferences.csv', index_col=0)
prefs
# Out:
#     cuisine        genre
# 0     Greek       horror
# 1    Indian        scifi
# 2  American      fantasy
# 3      Thai         tech
# 4    Indian  documentary

# %%
ds_full = pd.concat((ds_chars, prefs))
ds_full
# Out:
#      name     HP home_state   cuisine        genre
# 0    greg  200.0         WA       NaN          NaN
# 1   miles  200.0         WA       NaN          NaN
# 2    alan  170.0         TX       NaN          NaN
# 3  alison  300.0         DC       NaN          NaN
# 4  rachel  200.0         TX       NaN          NaN
# 0     NaN    NaN        NaN     Greek       horror
# 1     NaN    NaN        NaN    Indian        scifi
# 2     NaN    NaN        NaN  American      fantasy
# 3     NaN    NaN        NaN      Thai         tech
# 4     NaN    NaN        NaN    Indian  documentary

# %% [markdown]
# `pd.concat()`–– and many other pandas operations –– make use of an `axis` parameter. For this particular method I need to specify whether I want to concatenate the DataFrames *row-wise* (`axis=0`) or *column-wise* (`axis=1`). The default is `axis=0`, so let's override that!

# %%
# by implementing the axis=1 argument, we tell the concat to align cuisine/genre with the other rows.
ds_full = pd.concat([ds_chars, prefs], axis=1)
ds_full
# Out:
#      name   HP home_state   cuisine        genre
# 0    greg  200         WA     Greek       horror
# 1   miles  200         WA    Indian        scifi
# 2    alan  170         TX  American      fantasy
# 3  alison  300         DC      Thai         tech
# 4  rachel  200         TX    Indian  documentary

# %% [markdown]
# ## Back to the Center
#
# We have Intakes data and we have Outcomes data... time to merge!

# %%
# Peek at the outcomes data we already had in here
outcomes.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  \
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby
#
#    Calculated Age in days
# 0       63590400000000000
# 1       32054400000000000
# 2       31622400000000000
# 3       11059200000000000
# 4         518400000000000

# %%
# Read in the intakes data
intakes = pd.read_csv("data/Austin_Animal_Center_Intakes_022822.csv",
                      parse_dates=['DateTime'])
# Check it out
intakes.head()
# Out:
#   Animal ID     Name            DateTime     MonthYear  \
# 0   A786884   *Brock 2019-01-03 16:19:00  January 2019
# 1   A706918    Belle 2015-07-05 12:59:00     July 2015
# 2   A724273  Runster 2016-04-14 18:43:00    April 2016
# 3   A665644      NaN 2013-10-21 07:59:00  October 2013
# 4   A682524      Rio 2014-06-29 10:38:00     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
# Let's try merging on Animal ID
# we can use on= instead of left on= and right on= because the label is the same in both data sets
combined = outcomes.merge(intakes, on='Animal ID', suffixes=['_outcome', '_intake'])

# %%
# What was the result?
combined.head()
# Out:
#   Animal ID Name_outcome    DateTime_outcome MonthYear_outcome Date of Birth  \
# 0   A794011        Chunk 2019-05-08 18:20:00          May 2019    2017-05-02
# 1   A776359        Gizmo 2018-07-18 16:02:00          Jul 2018    2017-07-12
# 2   A821648          NaN 2020-08-16 11:38:00          Aug 2020    2019-08-16
# 3   A720371        Moose 2016-02-13 17:59:00          Feb 2016    2015-10-08
# 4   A720371        Moose 2016-02-13 17:59:00          Feb 2016    2015-10-08
#
#   Outcome Type Outcome Subtype Animal Type_outcome Sex upon Outcome  \
# 0    Rto-Adopt             NaN                 Cat    Neutered Male
# 1     Adoption             NaN                 Dog    Neutered Male
# 2   Euthanasia             NaN               Other          Unknown
# 3     Adoption             NaN                 Dog    Neutered Male
# 4     Adoption             NaN                 Dog    Neutered Male
#
#   Age upon Outcome  ...     DateTime_intake MonthYear_intake  \
# 0          2 years  ... 2019-05-02 16:51:00         May 2019
# 1           1 year  ... 2018-07-12 12:46:00        July 2018
# 2           1 year  ... 2020-08-16 10:10:00      August 2020
# 3         4 months  ... 2016-02-08 11:05:00    February 2016
# 4         4 months  ... 2016-02-15 10:37:00    February 2016
#
#                                Found Location      Intake Type  \
# 0                                 Austin (TX)  Owner Surrender
# 1           7201 Levander Loop in Austin (TX)            Stray
# 2  Armadillo Rd And Clubway Ln in Austin (TX)         Wildlife
# 3       Dove Dr And E Stassney in Austin (TX)            Stray
# 4                                 Austin (TX)  Owner Surrender
#
#   Intake Condition Animal Type_intake Sex upon Intake Age upon Intake  \
# 0           Normal                Cat   Neutered Male         2 years
# 1           Normal                Dog     Intact Male          1 year
# 2             Sick              Other         Unknown          1 year
# 3           Normal                Dog     Intact Male        4 months
# 4           Normal                Dog   Neutered Male        4 months
#
#                          Breed_intake       Color_intake
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4  Anatol Shepherd/Labrador Retriever               Buff
#
# [5 rows x 24 columns]

# %% [markdown]
# Let's discuss/explore: did that work the way we expected?
#
# -
#
# <details>
#     <summary>Observation Notes</summary>
#
# - We went from about 136k rows in each of the dataframes to 176k! Even using an inner join! Something seems off.
#
#
# </details>

# %%
# We might want to try something different
# Can we clean something to make a better merge?
print(combined.shape)
print(intakes.shape)
print(outcomes.shape)
# Out:
# (176664, 24)
# (136763, 12)
# (137097, 13)

# %%
# Try again

# %%
clean_combined_df.head()

# %% [markdown]
# # Level Up: Quick Column Name Clean Up Code
#
# Throwing a quick use of a lambda function your way:

# %%
outcomes_renamed = outcomes.rename(columns = lambda x: x.replace(" ", "_").lower())
outcomes_renamed.head()

# %% [markdown]
# # Level Up: `pandas.set_option()`

# %% [markdown]
# We can adjust how `pandas` works by setting options in advance.

# %% [markdown]
# For complete documentation, see [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html).

# %% [markdown]
# ## Block Scientific Notation

# %% [markdown]
# For example, suppose we want to prevent numbers from being displayed in scientific notation.

# %%
df = pd.DataFrame([[1e9, 2e9], [3e9, 4e9]])
df

# %% [markdown]
# Then we can use:

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

df

# %% [markdown]
# ## See More Rows

# %% [markdown]
# Or suppose we want `pandas` to show more rows.

# %%
df2 = pd.DataFrame(np.array(range(100)))
df2

# %% [markdown]
# In that case we can use:

# %%
pd.set_option('display.max_rows', 100)

df2
